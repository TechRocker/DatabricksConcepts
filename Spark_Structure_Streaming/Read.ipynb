# %%
df=(
  spark.readStream
  .format("cloudFiles")
  .option("cloudFiles.format", "json")
  .load("/Volumes/circuitbox/landing/operational_data/customers")
)

# %%
df.display()

# %%
(
    spark.readStream.format("cloudFiles")
    .option("cloudFiles.format", "csv")
    .option("cloudFiles.schemaLocation", "/Volumes/circuitbox/landing/operational_data/_schema/addresses")
    .option("cloudFiles.inferColumnTypes", "true")
    .load("/Volumes/circuitbox/landing/operational_data/addresses")
).display()
