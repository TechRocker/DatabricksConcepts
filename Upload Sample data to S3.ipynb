# %%
# Sample product data
data = [
    {"product_id": 1, "product_name": "Widget", "price": 19.99},
    {"product_id": 2, "product_name": "Gadget", "price": 29.99},
    {"product_id": 3, "product_name": "Thingamajig", "price": 9.99}
]

df = spark.createDataFrame(data)

# Specify external location (e.g., Azure Blob, S3, or DBFS)
external_path = "s3://dbxtrainingbucket/traning/products"

df.write.mode("overwrite").parquet(external_path)
