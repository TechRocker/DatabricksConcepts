# %%
# %sql
SELECT * FROM circuitbox.lakehouse.silver_addresses

# %%
# %sql
select
  *
from
  system.billing.usage
where
  sku_name = 'PREMIUM_ALL_PURPOSE_SERVERLESS_COMPUTE_INDIA_CENTRAL'
  and usage_date>date_add(current_date(),-7)
order by
  usage_start_time desc

# %%
# %sql
select
  *
from
  system.billing.usage
where
  --sku_name = 'PREMIUM_ALL_PURPOSE_SERVERLESS_COMPUTE_INDIA_CENTRAL'
  --and 
  usage_date>date_add(current_date(),-7)
order by
  usage_start_time desc
