# %%
# %sql
CREATE OR REPLACE FUNCTION main.default.random_val()
RETURNS DOUBLE
LANGUAGE PYTHON
AS $$
import random
return random.random()
$$;

# %%
# %sql
select main.default.random_val()

# %%
# %sql
select * from range(1,200)
